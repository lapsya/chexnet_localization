# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pydicom
import glob
from skimage import io, transform

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision import transforms, utils

from sklearn.model_selection import train_test_split

# %%
def parse_data(df):
    """
    Method to read a CSV file (Pandas dataframe) and parse the 
    data into the following nested dictionary:

      parsed = {
        
        'patientId-00': {
            'dicom': path/to/dicom/file,
            'label': either 0 or 1 for normal or pnuemonia, 
            'boxes': list of box(es)
        },
        'patientId-01': {
            'dicom': path/to/dicom/file,
            'label': either 0 or 1 for normal or pnuemonia, 
            'boxes': list of box(es)
        }, ...

      }

    """
    # --- Define lambda to extract coords in list [y, x, height, width]
    extract_box = lambda row: list(row[['y', 'x', 'height', 'width']]) #[row['y'], row['x'], row['height'], row['width']]

    parsed = {}
    for n, row in df.iterrows():
        # --- Initialize patient entry into parsed 
        pid = row['patientId']
        if pid not in parsed:
            parsed[pid] = {
                'dicom': f'train_images/{pid}.dcm',
                'label': row['Target'],
                'boxes': []}

        # --- Add box if opacity is present
        if parsed[pid]['label'] == 1:
            parsed[pid]['boxes'].append(extract_box(row))

    return parsed

def draw(data):
    """
    Method to draw single patient with bounding box(es) if present 

    """
    # --- Open DICOM file
    d = pydicom.read_file(data['dicom'])
    im = d.pixel_array

    # --- Convert from single-channel grayscale to 3-channel RGB
    im = np.stack([im] * 3, axis=2)

    # --- Add boxes with random color if present
    for box in data['boxes']:
        rgb = np.floor(np.random.rand(3) * 256).astype('int')
        im = overlay_box(im=im, box=box, rgb=rgb, stroke=6)
    
    plt.figure(figsize=(10, 10))
    plt.imshow(im, cmap=plt.cm.gist_gray)
    plt.axis('off')

def overlay_box(im, box, rgb, stroke=1):
    """
    Method to overlay single box on image

    """
    # --- Convert coordinates to integers
    box = [int(b) for b in box]
    
    # --- Extract coordinates
    y1, x1, height, width = box
    y2 = y1 + height
    x2 = x1 + width

    im[y1:y1 + stroke, x1:x2] = rgb
    im[y2:y2 + stroke, x1:x2] = rgb
    im[y1:y2, x1:x1 + stroke] = rgb
    im[y1:y2, x2:x2 + stroke] = rgb

    return im

# %%
df = pd.read_csv('stage_2_train_labels.csv')

parsed = parse_data(df)

# %%
patientId = df['patientId'][8]
print('Just a checking that everything is working fine...')
print(parsed[patientId])
# Out:
# Just a checking that everything is working fine...
# {'dicom': 'train_images/00704310-78a8-4b38-8475-49f4573b2dbb.dcm', 'label': 1, 'boxes': [[577.0, 323.0, 104.0, 160.0], [575.0, 695.0, 137.0, 162.0]]}

# %%
draw(parsed[patientId])

# %%
class CXRDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, parsed_dataset, transform=None):
        self.parsed = parsed_dataset
        self.transform = transform
        self.pids = list(self.parsed.keys())

    def __len__(self):
        return len(self.parsed)

    def __getitem__(self, idx):
        pid = self.pids[idx]
        cxr_image = pydicom.read_file(self.parsed[pid]['dicom']).pixel_array
        cxr_image = np.stack([cxr_image] * 3, axis=2)
        
        label = self.parsed[pid]['label']

        if self.transform:
            cxr_image = self.transform(cxr_image)
        
        sample = (cxr_image, label)
        return sample

# %%
parsed_train, parsed_val = map(lambda df: df.T.to_dict(), train_test_split(pd.DataFrame(parsed).T, train_size=0.7, test_size=0.3))

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
])

train_dataset = CXRDataset(parsed_train, transform)
val_dataset = CXRDataset(parsed_val, transform)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=4,)
val_loader = DataLoader(val_dataset, batch_size=16, num_workers=4,)

# %%
class DenseNet121(nn.Module):
    def __init__(self):
        super(DenseNet121, self).__init__()
        self.model = torchvision.models.densenet121(pretrained=True)
        self.pre_gap = nn.Sequential(self.model.features, nn.ReLU())
        
        self.classifier = nn.Linear(self.model.classifier.in_features, 2)
        
        for params in self.model.parameters():
            params.requires_grad = False
            
        self.model.classifier = self.classifier
        
    
    def forward(self, x):
        out = self.pre_gap(x)
        out = F.adaptive_avg_pool2d(out, (1, 1)).view(out.size(0), -1)
        out = self.classifier(out)
        return out
    
    
class LayerActivations():
    
    def __init__(self, model):
        self.hooks = []
        self.hooks.append(model.pre_gap.register_forward_hook(self.hook_fn))
        self.activations = []
    
    def hook_fn(self, module, input, output):
        self.activations.append(output)
    
    def remove(self):
        for hook in self.hooks:
            hook.remove()

# %%
model = DenseNet121()
optimizer = torch.optim.Adam(model.classifier.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# %%
def accuracy_loss(model, dataloader, n_batches=20, use_cuda=True, calc_loss=False, criterion=None):
    with torch.no_grad():
        acc = 0
        losses = []
        acc_items_len = 0
        for i, (x, y) in enumerate(dataloader):
            if use_cuda:
                x, y = x.cuda(), y.cuda()
            
            y_pred = model(x)
            prediction = torch.argmax(y_pred, dim=1)
            if i < n_batches:
                acc_items_len += y.shape[0]
                acc += (prediction == y).sum().to(dtype=torch.float).item()
            if calc_loss:
                loss = criterion(y_pred)
                losses.append(loss.item())
            
        acc /= y.shape[0]
    if calc_loss:
        return acc, losses
    return acc

# %%
def train(model, train_loader, val_loader, optimizer, criterion, n_epochs=100, use_cuda=True):
    if use_cuda:
        model = model.cuda()
    train_loss_hist = []
    mean_train_loss_hist = []
    val_loss_hist = []
    mean_val_loss_hist = []
    
    best_val_acc = 0
    train_acc_hist = []
    val_acc_hist = []
    for epoch in range(n_epochs):
        print('Epoch {}/{}'.format(epoch + 1, n_epochs))
        print('-' * 10)
        
        train_losses = []
        for i, (x, y) in enumerate(train_loader):
            if use_cuda:
                x, y = x.cuda(), y.cuda()
            
            y_pred = model(x)
            loss = criterion(y_pred, y)
            train_losses.append(loss.item())

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        train_loss_hist += train_losses
        mean_train_loss = sum(train_losses) / len(train_loader)
        mean_train_loss_hist.append(mean_train_loss)
        train_acc = accuracy_loss(model, train_loader, use_cuda=use_cuda)
        train_acc_hist.append(train_acc)
        
        val_acc, val_losses = accuracy_loss(model, val_loader, use_cuda=use_cuda, calc_loss=True, criterion=criterion)
        val_hist_loss += val_losses
        mean_val_loss = sum(val_losses) / len(val_loader)
        mean_val_loss_hist.append(mean_val_loss)
        val_acc_hist.append(val_acc)
        
        if val_acc > best_val_acc:
            torch.save(model.state_dict(), 'best_model.pt')

        print(f'epoch: {epoch}, train loss: {mean_train_loss:.5f}, test loss: {mean_val_loss}')
        print(f'train acc: {100 * train_acc:.2f}%, val acc: {100 * val_acc:.2f}%, took: {time.time() - t:.2f} sec')
        
        display.clear_output(wait=True)
        fig, ax = plt.subplots(1, 2, figsize=(14, 5))

        ax[0].set_title("Loss")
        ax[0].set_xlabel("#epoch")
        ax[0].set_ylabel("loss")
        ax[0].plot(range(len(mean_train_loss_hist)), mean_train_loss_hist, label='train')
        ax[0].plot(range(len(mean_test_loss_hist)), mean_test_loss_hist, label='val')
        
        ax[1].set_title("Accuracy")
        ax[1].set_xlabel("#epoch")
        ax[1].set_ylabel("accuracy")
        ax[1].plot(range(len(train_acc_hist)), train_acc_hist, label='train')
        ax[1].plot(range(len(val_acc_hist)), val_acc_hist, label='val')
        
        plt.legend()
        plt.show()
        
        
    model.load_state_dict('best_model.pt')
    return train_loss_hist, mean_train_loss_hist, val_loss_hist, mean_val_loss_hist

results = train(model, train_loader, val_loader, optimizer, criterion, n_epochs=100, use_cuda=False)
# Out:
# Epoch 1/100
# ----------
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/usr/local/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-105-144e8e324e63> in <module>
#      67     return train_loss_hist, mean_train_loss_hist, val_loss_hist, mean_val_loss_hist
#      68
# ---> 69 results = train(model, train_loader, val_loader, optimizer, criterion, n_epochs=100, use_cuda=False)
#
# <ipython-input-105-144e8e324e63> in train(model, train_loader, val_loader, optimizer, criterion, n_epochs, use_cuda)
#      19                 x, y = x.cuda(), y.cuda()
#      20
# ---> 21             y_pred = model(x)
#      22             loss = criterion(y_pred, y)
#      23             train_losses.append(loss.item())
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-102-b1848045fa3d> in forward(self, x)
#      14
#      15     def forward(self, x):
# ---> 16         out = self.pre_gap(x)
#      17         out = F.adaptive_avg_pool2d(out, (1, 1)).view(out.size(0), -1)
#      18         out = self.classifier(out)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/site-packages/torchvision/models/densenet.py in forward(self, x)
#      31
#      32     def forward(self, x):
# ---> 33         new_features = super(_DenseLayer, self).forward(x)
#      34         if self.drop_rate > 0:
#      35             new_features = F.dropout(new_features, p=self.drop_rate, training=self.training)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     318     def forward(self, input):
#     319         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 320                         self.padding, self.dilation, self.groups)
#     321
#     322
#
# KeyboardInterrupt:
